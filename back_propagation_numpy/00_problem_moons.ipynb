# %%
import numpy as np

# %%
from problem import make_problem
from viz import make_plot

# %%
N_SAMPLES = 10000
TEST_SIZE = 0.1

X_train, X_test, y_train, y_test = make_problem(N_SAMPLES, TEST_SIZE)

# %%
make_plot(X_test, y_test, "origin data", file_name=None)
