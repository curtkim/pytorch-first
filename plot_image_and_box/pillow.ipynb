# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

image = Image.open('car.jpg', 'r')
print(image) #<PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=3500x2139

fig, ax = plt.subplots(figsize=(10,10))
ax.imshow(np.asarray(image))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=3500x2139 at 0x7FE910F1C850>
